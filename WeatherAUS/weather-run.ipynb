# %% [markdown]
# ## Running the program

# %%
# !python weather.py
# Out:
# The program has ended correctly.

# %% [markdown]
# ### Data processing logic

# %% [markdown]
# ```python
# if __name__ == '__main__':
#     # Extracting and saving settings from a report file
#     # python weather.py report/report_[...].json
#     save_old_settings(sys.argv, save_to='settings_OLD.json')
#
#     settings = get_settings('settings.json')
#
#     # Updating we.COLUMN_DATE / we.COLUMN_CITY
#     set_column(settings, we)
#
#     report = {'preprocessing': {}}
#
#     # === Working with a dataset ===
#     data = load_data(settings)  # Step 0
#     data = convert_dt(settings, data) # Step 1
#     data = to_dropna_rows(settings, data)  # Step 2
#     # data.to_pickle("data/data-2.pkl")
#
#     # === Working with features ===
#     features = get_features(settings)
#
#     data = to_drop(features, data)  # Step 3
#     data = to_dropna_cols(features, data)  # Step 4
#     data = to_fillna(features, data)  # Step 5
#     # data.to_pickle("data/data-5.pkl")
#     data = to_upd_outlier(features, data)  # Step 6
#     data.to_pickle("data/data-6.pkl")
#     data = to_encode(features, data)  # Step 7
#     data.to_pickle("data/data-7.pkl")
#
#     report['settings'] = settings
#     save_report(report, dir_name='report')
#
#     print("\nThe program has ended correctly.\n")
# ```

# %% [markdown]
# ### Information about the program

# %%
import weather

# %%
help(weather)
# Out:
# Help on module weather:
#
# NAME
#     weather
#
# DESCRIPTION
#     Predict next-day rain (on the target variable RainTomorrow).
#     The dataset contains about 10 years of daily weather
#     observations from many locations across Australia.
#
#     Link: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package
#
#     RainTomorrow is the target variable to predict.
#     It means - did it rain the next day, Yes or No? This colum is Yes if
#     the rain for that day was 1mm or more.
#
# FUNCTIONS
#     convert_dt(settings, data)
#         \o/
#
#     get_features(settings)
#         \o/
#
#     get_settings(file_name)
#         \o/
#
#     load_data(settings)
#         \o/
#
#     save_old_settings(arguments, save_to)
#         \o/
#
#     save_preprocessing(who_save, shape=None, info='')
#         \o/
#
#     save_report(report, dir_name=None)
#         \o/
#
#     set_column(settings, utils)
#         \o/
#
#     to_drop(features, data)
#         \o/
#
#     to_dropna_cols(features, data)
#         \o/
#
#     to_dropna_rows(settings, data)
#         \o/
#
#     to_encode(features, data)
#         \o/
#
#     to_fillna(features, data)
#         \o/
#
#     to_upd_outlier(features, data, asymmetric=0.5, upd_all=False)
#         \o/
#
# FILE
#     /home/anatoly/Private/DataScience/Tasks/weather/weather.py

# %% [markdown]
# ### Information about the module

# %%
import utils_weather

# %%
help(utils_weather)
# Out:
# Help on module utils_weather:
#
# NAME
#     utils_weather - Custom utilities for working with weather data.
#
# FUNCTIONS
#     isna_stats(df, columns=None, n=None, more_than=None)
#         The percentage of missing values in the dataset.
#         There is a choice of columns, filter by top values / more than.
#
#     notna_column(df, column, period='month', total=False)
#         Table of values by columns (grouped by location and period).
#         Period - year or month or month-year. And the total amount.
#
#     outlier_stats(df)
#         The percentage of outlier values in the dataset.
#         There is a choice of columns, filter by top values.
#
#     test_compare_values(df, df_test, column_name, info=False, diff=False)
#         Get old data (column) and new from the dataframes.
#         Additional information / difference between columns.
#
#     test_fillna_column(df, column_name)
#         Trying all the methods for filling NaN values in a column.
#
#     test_get_group_indx(df, location, x_year, x_month=None)
#         Get a list of indexes by multi-index of the selected group.
#         Possible options: location and year (required), month.
#
#     try_encode(df, name_column, method)
#         Encoding values with the chosen method.
#
#     try_fillna_column(df, column_name, method='obj-easy')
#         Filling missing values with the chosen method.
#
#     try_outlier_upd(df, name_column, asymmetric, method)
#         Filling outlier values with the chosen method.
#
# DATA
#     COLUMN_CITY = 'Location'
#     COLUMN_DATE = 'Date'
#     COLUMN_TARGET = 'RainTomorrow'
#
# FILE
#     /home/anatoly/Private/DataScience/Tasks/weather/utils_weather.py

# %% [markdown]
# ### Information about settings

# %%
import json

# %%
with open("settings.json", "r") as read_file:
    settings = json.load(read_file)

# %%
print(json.dumps(settings, indent=4))
# Out:
# {
#     "path_to_csv": "input/weatherAUS.csv",
#     "targets": {
#         "1": {
#             "column": "RainTomorrow",
#             "models": []
#         }
#     },
#     "dropna": {
#         "status": true,
#         "thresh": 5
#     },
#     "columns": {
#         "date": "Date",
#         "city": "Location"
#     },
#     "features": {
#         "1": {
#             "name": "MinTemp",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "2": {
#             "name": "MaxTemp",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "3": {
#             "name": "Rainfall",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "4": {
#             "name": "Evaporation",
#             "drop": true,
#             "dropna": false,
#             "fillna": "num-smart",
#             "encoder": {
#                 "update": false,
#                 "method": ""
#             }
#         },
#         "5": {
#             "name": "Sunshine",
#             "drop": true,
#             "dropna": false,
#             "fillna": "num-smart",
#             "encoder": {
#                 "update": false,
#                 "method": ""
#             }
#         },
#         "6": {
#             "name": "WindGustDir",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "encoder": {
#                 "update": true,
#                 "method": "binary"
#             }
#         },
#         "7": {
#             "name": "WindGustSpeed",
#             "drop": false,
#             "dropna": false,
#             "fillna": "obj-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "8": {
#             "name": "WindDir9am",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "encoder": {
#                 "update": true,
#                 "method": "binary"
#             }
#         },
#         "9": {
#             "name": "WindDir3pm",
#             "drop": false,
#             "dropna": false,
#             "fillna": "obj-smart",
#             "encoder": {
#                 "update": true,
#                 "method": "binary"
#             }
#         },
#         "10": {
#             "name": "WindSpeed9am",
#             "drop": false,
#             "dropna": false,
#             "fillna": "obj-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "11": {
#             "name": "WindSpeed3pm",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "12": {
#             "name": "Humidity9am",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "13": {
#             "name": "Humidity3pm",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "14": {
#             "name": "Pressure9am",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "15": {
#             "name": "Pressure3pm",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "16": {
#             "name": "Cloud9am",
#             "drop": true,
#             "dropna": false,
#             "fillna": "num-smart",
#             "encoder": {
#                 "update": false,
#                 "method": ""
#             }
#         },
#         "17": {
#             "name": "Cloud3pm",
#             "drop": true,
#             "dropna": false,
#             "fillna": "num-smart",
#             "encoder": {
#                 "update": false,
#                 "method": ""
#             }
#         },
#         "18": {
#             "name": "Temp9am",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "19": {
#             "name": "Temp3pm",
#             "drop": false,
#             "dropna": false,
#             "fillna": "num-smart",
#             "outlier": {
#                 "update": true,
#                 "method": "border"
#             }
#         },
#         "20": {
#             "name": "RainToday",
#             "drop": false,
#             "dropna": false,
#             "fillna": "obj-smart",
#             "encoder": {
#                 "update": true,
#                 "method": "yes_no"
#             }
#         },
#         "21": {
#             "name": "RainTomorrow",
#             "drop": false,
#             "dropna": false,
#             "fillna": "obj-smart",
#             "encoder": {
#                 "update": true,
#                 "method": "yes_no"
#             }
#         }
#     }
# }

# %% [markdown]
# ### Information about reports

# %%
with open("report/report_2021-06-22___01-01-35.json", "r") as read_file:
    report = json.load(read_file)

# %%
print(json.dumps(report, indent=4))
# Out:
# {
#     "preprocessing": {
#         "load_data": {
#             "time": "01:01:32 / 633486",
#             "rows": 145460,
#             "cols": 23,
#             "info": "Size 3345580 / Missing values 343248"
#         },
#         "convert_dt": {
#             "time": "01:01:32 / 692351",
#             "rows": 145460,
#             "cols": 23,
#             "info": "Dtype datetime64[ns]"
#         },
#         "to_dropna_rows": {
#             "time": "01:01:32 / 865391",
#             "rows": 145167,
#             "cols": 23,
#             "info": false
#         },
#         "to drop": {
#             "time": "01:01:32 / 913926",
#             "rows": 145167,
#             "cols": 19,
#             "info": "Drop: Evaporation, Sunshine, Cloud9am, Cloud3pm"
#         },
#         "to_dropna_cols": {
#             "time": "01:01:32 / 913988",
#             "rows": 145167,
#             "cols": 19,
#             "info": ""
#         },
#         "to_fillna": {
#             "time": "01:01:33 / 221002",
#             "rows": 145167,
#             "cols": 19,
#             "info": "Missing values 0"
#         },
#         "to_upd_outlier": {
#             "time": "01:01:33 / 463065",
#             "rows": 145167,
#             "cols": 19,
#             "info": {
#                 "1": "Feature 'MinTemp' by 'border' method",
#                 "2": "Feature 'MaxTemp' by 'border' method",
#                 "3": "Feature 'Rainfall' by 'border' method",
#                 "7": "Feature 'WindGustSpeed' by 'border' method",
#                 "10": "Feature 'WindSpeed9am' by 'border' method",
#                 "11": "Feature 'WindSpeed3pm' by 'border' method",
#                 "12": "Feature 'Humidity9am' by 'border' method",
#                 "13": "Feature 'Humidity3pm' by 'border' method",
#                 "14": "Feature 'Pressure9am' by 'border' method",
#                 "15": "Feature 'Pressure3pm' by 'border' method",
#                 "18": "Feature 'Temp9am' by 'border' method",
#                 "19": "Feature 'Temp3pm' by 'border' method"
#             }
#         },
#         "to_encode": {
#             "time": "01:01:34 / 891518",
#             "rows": 145167,
#             "cols": 31,
#             "info": {
#                 "6": "Feature 'WindGustDir' by 'binary' method",
#                 "8": "Feature 'WindDir9am' by 'binary' method",
#                 "9": "Feature 'WindDir3pm' by 'binary' method",
#                 "20": "Feature 'RainToday' by 'yes_no' method",
#                 "21": "Feature 'RainTomorrow' by 'yes_no' method"
#             }
#         }
#     },
#     "settings": {
#         "path_to_csv": "input/weatherAUS.csv",
#         "targets": {
#             "1": {
#                 "column": "RainTomorrow",
#                 "models": []
#             }
#         },
#         "dropna": {
#             "status": true,
#             "thresh": 5
#         },
#         "columns": {
#             "date": "Date",
#             "city": "Location"
#         },
#         "features": {
#             "1": {
#                 "name": "MinTemp",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "2": {
#                 "name": "MaxTemp",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "3": {
#                 "name": "Rainfall",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "4": {
#                 "name": "Evaporation",
#                 "drop": true,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "encoder": {
#                     "update": false,
#                     "method": ""
#                 }
#             },
#             "5": {
#                 "name": "Sunshine",
#                 "drop": true,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "encoder": {
#                     "update": false,
#                     "method": ""
#                 }
#             },
#             "6": {
#                 "name": "WindGustDir",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "encoder": {
#                     "update": true,
#                     "method": "binary"
#                 }
#             },
#             "7": {
#                 "name": "WindGustSpeed",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "obj-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "8": {
#                 "name": "WindDir9am",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "encoder": {
#                     "update": true,
#                     "method": "binary"
#                 }
#             },
#             "9": {
#                 "name": "WindDir3pm",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "obj-smart",
#                 "encoder": {
#                     "update": true,
#                     "method": "binary"
#                 }
#             },
#             "10": {
#                 "name": "WindSpeed9am",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "obj-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "11": {
#                 "name": "WindSpeed3pm",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "12": {
#                 "name": "Humidity9am",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "13": {
#                 "name": "Humidity3pm",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "14": {
#                 "name": "Pressure9am",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "15": {
#                 "name": "Pressure3pm",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "16": {
#                 "name": "Cloud9am",
#                 "drop": true,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "encoder": {
#                     "update": false,
#                     "method": ""
#                 }
#             },
#             "17": {
#                 "name": "Cloud3pm",
#                 "drop": true,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "encoder": {
#                     "update": false,
#                     "method": ""
#                 }
#             },
#             "18": {
#                 "name": "Temp9am",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "19": {
#                 "name": "Temp3pm",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "num-smart",
#                 "outlier": {
#                     "update": true,
#                     "method": "border"
#                 }
#             },
#             "20": {
#                 "name": "RainToday",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "obj-smart",
#                 "encoder": {
#                     "update": true,
#                     "method": "yes_no"
#                 }
#             },
#             "21": {
#                 "name": "RainTomorrow",
#                 "drop": false,
#                 "dropna": false,
#                 "fillna": "obj-smart",
#                 "encoder": {
#                     "update": true,
#                     "method": "yes_no"
#                 }
#             }
#         }
#     }
# }
